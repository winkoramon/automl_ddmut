# %%
#####THIS CODE aims to run Autosklearn v1 on regressor data#####

#Adjustable parameters
main_path = '/home/korawich/Desktop/AutoML/automl_ddmut/'

time_left_for_this_task = 72000 #1 hrs
per_run_time_limit = 300
memory_limit = 9280

debug = 1 #0 = not, 1 = yes -> in debug mode, only ~30 features are used to test the pipeline

# %%
#Datafile #change here to use different data
data_path = main_path + 'AutoML/Dataset/DDMut_data/'
gbsig_path = main_path + 'Dataset/DDMut_data/Graph-based/'
result_path = main_path + 'Dataset/DDMut_data/Results/'
final_path = main_path + 'Dataset/DDMut_data/Final/'

#train_info_path  = final_path + 'train_info.csv'
#test_1_info_path = final_path + 'test_1_info.csv'
#test_2_info_path = final_path + 'test_2_info.csv'
#test_3_info_path = final_path + 'test_3_info.csv'

train_X_path  = final_path + 'final_train_X.csv'
test_1_X_path = final_path + 'final_test_1_X.csv'
test_2_X_path = final_path + 'final_test_2_X.csv'
test_3_X_path = final_path + 'final_test_3_X.csv'

train_y_path  = final_path + 'train_y.csv'
test_1_y_path = final_path + 'test_1_y.csv'
test_2_y_path = final_path + 'test_2_y.csv'
test_3_y_path = final_path + 'test_3_y.csv'

# %%
import numpy as np
import pandas as pd

from pprint import pprint

import sklearn.datasets
import sklearn.metrics

import autosklearn.regression

import warnings
warnings.filterwarnings('ignore')

from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_validate, KFold

# %%
#Code path 
alg_path = main_path + 'Algorithm/Auto-sklearn/'

# %% [markdown]
# loading data

# %%
X_train = pd.read_csv(train_X_path, index_col=0)
X_test_1 = pd.read_csv(test_1_X_path, index_col=0)
X_test_2 = pd.read_csv(test_2_X_path, index_col=0)
X_test_3 = pd.read_csv(test_3_X_path, index_col=0)

y_train = pd.read_csv(train_y_path, index_col=0)
y_test_1 = pd.read_csv(test_1_y_path, index_col=0)
y_test_2 = pd.read_csv(test_2_y_path, index_col=0)
y_test_3 = pd.read_csv(test_3_y_path, index_col=0)

# %%
#Check size of datasets
print('X_train.shape = ', X_train.shape)
print('X_test_1.shape = ', X_test_1.shape)
print('X_test_2.shape = ', X_test_2.shape)
print('X_test_3.shape = ', X_test_3.shape)
# Out:
# X_train.shape =  (9028, 896)
# X_test_1.shape =  (552, 896)
# X_test_2.shape =  (1304, 896)
# X_test_3.shape =  (2024, 896)

# %%
#load list of features
feat_list_path = main_path + 'Dataset/DDMut_data/Feat_list/'
gbsig_feat_list_path = feat_list_path + 'gbsig_feat_list.csv'
seq_feat_list_path = feat_list_path + 'seq_feat_list.csv'
str_feat_list_path = feat_list_path + 'str_feat_list.csv'

all_feat_result_path = result_path + 'tpot_default_params.csv'
gbsig_feat_result_path = result_path + 'tpot_default_params_gbsig.csv'
seq_feat_result_path = result_path + 'tpot_default_params_seq.csv'
str_feat_result_path = result_path + 'tpot_default_params_str.csv'

gbs_feat = pd.read_csv(gbsig_feat_list_path, index_col=0)
seq_feat = pd.read_csv(seq_feat_list_path, index_col=0)
str_feat = pd.read_csv(str_feat_list_path, index_col=0)
all_feat = pd.concat([seq_feat, str_feat, gbs_feat], ignore_index=True)

# %%
if debug == 0:
    features_sets = [
        ('all_feat', all_feat, all_feat_result_path),
        ('seq_feat', seq_feat, seq_feat_result_path),
        ('str_feat', str_feat, str_feat_result_path),
        ('gbs_feat', gbs_feat, gbsig_feat_result_path)
                    ]
elif debug == 1:
    features_sets = [
        #('all_feat', all_feat, all_feat_result_path),
        #('seq_feat', seq_feat, seq_feat_result_path)
        ('str_feat', str_feat, str_feat_result_path),
        #('gbs_feat', gbs_feat, gbsig_feat_result_path)   
    ]

# %% [markdown]
# Autosklearn

# %%
#Set search space -> #same as in table 18 of Autosklearn 2.0 paper (2020)
#It's only using iterative models and only preprocessing to encode data into suitable format
#https://arxiv.org/pdf/2007.04074
#But table 18 is classification. We adapt them to regression counterpart.

search_space_dict = {
            'regressor': [
                "extra_trees", 
                "gradient_boosting",
                "mlp",
                #"passive_aggressive", #No PA in regression
                "random_forest",
                "sgd"],
            'feature_preprocessor': ["no_preprocessing"]
}

# %%
automl = autosklearn.regression.AutoSklearnRegressor(
    ensemble_size=3, #use in the paper, always choosing the current best model
    initial_configurations_via_metalearning=0,
    n_jobs=-1,
    allow_string_features=False,
    time_left_for_this_task=time_left_for_this_task, #need to be changed
    per_run_time_limit=per_run_time_limit, #need to be changed
    resampling_strategy="cv",
    resampling_strategy_arguments={"folds": 5}, #should be ten
    seed=1,
    include=search_space_dict,
    exclude=None,
    delete_tmp_folder_after_terminate=False,
    memory_limit=memory_limit)

# %%
results = []
for feat_name, feat_list, result_path in features_sets:
    print('running - feat_name: ', feat_name)
    X_train_sel  = X_train[feat_list.values.flatten()]
    X_test_1_sel = X_test_1[feat_list.values.flatten()]
    X_test_2_sel = X_test_2[feat_list.values.flatten()]
    X_test_3_sel = X_test_3[feat_list.values.flatten()]
     
    automl.fit(X_train_sel, y_train, dataset_name="ddmut")
    
    print(automl.leaderboard())
    
    #During fit(), models are fit on individual cross-validation folds.
    #Refit use models on whole datasets
    automl.refit(X_train_sel.copy(), y_train)
    
    #Report the models found by Auto-sklearn
    pprint(automl.show_models(), indent=4)
    
    #Report statistics about the search
    print(automl.sprint_statistics())
    
    #Test on a blind test
    y_pred_test_1 = automl.predict(X_test_1_sel)
    rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_test_1))
    r2_1 = r2_score(y_test_1, y_pred_test_1)
    pearson_corr_1, _ = pearsonr(y_test_1.values.flatten(), y_pred_test_1.flatten())
    print('score for test 1 - RMSE = ', rmse_1, ' - R2 = ', r2_1, ' - Pearson = ', pearson_corr_1)

    y_pred_test_2 = automl.predict(X_test_2_sel)
    rmse_2 = np.sqrt(mean_squared_error(y_test_2, y_pred_test_2))
    r2_2 = r2_score(y_test_2, y_pred_test_2)
    pearson_corr_2, _ = pearsonr(y_test_2.values.flatten(), y_pred_test_2.flatten())
    print('score for test 2 - RMSE = ', rmse_2, ' - R2 = ', r2_2, ' - Pearson = ', pearson_corr_2)
    
    y_pred_test_3 = automl.predict(X_test_3_sel)
    rmse_3 = np.sqrt(mean_squared_error(y_test_3, y_pred_test_3))
    r2_3 = r2_score(y_test_3, y_pred_test_3)
    pearson_corr_3, _ = pearsonr(y_test_3.values.flatten(), y_pred_test_3.flatten())
    print('score for test 3 - RMSE = ', rmse_3, ' - R2 = ', r2_3, ' - Pearson = ', pearson_corr_3)
    
    #10-fold CV
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    rmse_scores = []
    r2_scores = []
    pearson_corrs = []
    
    for train_index, test_index in kfold.split(X_train_sel[feat_list.values.flatten()]):
        X_train_fold, X_test_fold = X_train_sel[feat_list.values.flatten()].loc[train_index], X_train_sel[feat_list.values.flatten()].loc[test_index]
        y_train_fold, y_test_fold = y_train.loc[train_index], y_train.loc[test_index]
        
        # Train the model on the current fold
        automl.refit(X_train_fold, y_train_fold)
        y_pred_fold = automl.predict(X_test_fold)
        
        # Calculate RMSE, R2, and Pearson correlation
        rmse = np.sqrt(mean_squared_error(y_test_fold, y_pred_fold))
        r2 = r2_score(y_test_fold, y_pred_fold)
        pearson_corr, _ = pearsonr(y_test_fold.values.flatten(), y_pred_fold.flatten())
        
        # Store the scores
        rmse_scores = np.append(rmse_scores, rmse)
        r2_scores = np.append(r2_scores, r2)
        pearson_corrs = np.append(pearson_corrs, pearson_corr)
        
    results.append({
        "Method": "Autosklearn_v1",
        "Feat set": feat_name,
        "Model params": automl.show_models(),
        "Running info": automl.sprint_statistics(),
        "CV Mean RMSE (10-fold)": round(np.mean(rmse_scores), 3), 
        "CV Std RMSE (10-fold)": round(np.std(rmse_scores), 3),
        "CV Mean R2 (10-fold)": round(np.mean(r2_scores), 3),
        "CV Std R2 (10-fold)": round(np.std(r2_scores), 3),
        "CV Mean Pearson (10-fold)": round(np.mean(pearson_corrs), 3),
        "CV Std Pearson (10-fold)": round(np.std(pearson_corrs), 3),
        "Test 1 RMSE": round(rmse_1, 3),
        "Test 1 R2"  : round(r2_1, 3),
        "Test 1 Pearson" : round(pearson_corr_1, 3),
        "Test 2 RMSE": round(rmse_2, 3),
        "Test 2 R2"  : round(r2_2, 3),
        "Test 2 Pearson" : round(pearson_corr_2, 3),
        "Test 3 RMSE": round(rmse_3, 3),
        "Test 3 R2"  : round(r2_3, 3),
        "Test 3 Pearson" : round(pearson_corr_3, 3)
        })
    results_df = pd.DataFrame(results)
    
    results_df_autosklearn_save_path = result_path + 'Autosklearn_ddmut_results.csv'
    results_df.to_csv(results_df_autosklearn_save_path)
# Out:
# running - feat_name:  str_feat
# [WARNING] [2024-08-30 17:18:37,815:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:18:42,689:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:18:49,094:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:18:54,861:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:18:59,436:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:04,351:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:09,231:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:16,344:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:22,443:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:28,411:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:35,072:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:36,327:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:42,758:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:51,035:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:19:57,404:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:03,623:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:10,674:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:16,929:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:23,898:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:30,957:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:38,154:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:45,978:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:20:52,116:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:00,045:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:07,362:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:16,461:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:23,089:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:29,612:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:36,292:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:42,966:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:49,455:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17:21:55,744:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-30 17
Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:47:54,582:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:48:14,280:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:48:24,080:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:48:39,582:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:48:58,345:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:49:12,860:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:49:25,684:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:49:35,706:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:49:50,257:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:49:59,993:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:50:07,721:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:50:19,369:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:50:29,180:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:50:38,930:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:50:54,806:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:51:05,084:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:51:17,746:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:51:36,613:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:51:46,332:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:51:58,279:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:52:11,719:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:52:31,286:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:52:41,439:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:52:50,058:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:53:07,602:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:53:23,149:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:53:32,466:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:53:53,470:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:54:07,926:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:54:22,587:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:54:37,302:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:54:53,036:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:55:06,341:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:55:31,909:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:55:42,181:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:55:59,834:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:56:07,966:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:56:25,806:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:56:35,379:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:56:43,387:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:56:59,195:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:57:09,376:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:57:22,167:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:57:29,855:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:57:47,139:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:57:57,008:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:58:12,352:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:58:22,437:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:58:32,376:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:58:39,497:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:58:56,266:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:59:10,246:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:59:29,211:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:59:45,520:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 12:59:59,238:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:00:11,679:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:00:22,135:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:00:32,202:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:00:46,874:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:01:09,322:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:01:25,539:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:01:46,197:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:02:01,718:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:02:17,590:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:02:25,741:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:02:42,538:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:02:59,503:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:03:10,470:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:03:19,773:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:03:35,747:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:03:45,589:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:03:56,155:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:04:12,398:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:04:28,417:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:04:45,760:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:04:56,737:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:05:09,922:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:05:21,199:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:05:35,343:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:05:47,449:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:05:59,994:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:06:22,571:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:06:34,551:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:06:50,582:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:07:04,774:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:07:22,614:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:07:42,250:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:08:01,057:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:08:09,575:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:08:29,038:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:08:44,567:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:09:01,782:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:09:19,258:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:09:26,752:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:09:39,742:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:09:56,423:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:10:16,371:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:10:27,257:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:10:42,677:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:10:53,723:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:11:03,193:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:11:12,653:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:11:28,292:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:11:36,255:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:11:48,281:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:11:58,281:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:12:08,698:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:12:18,732:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:12:34,706:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:12:43,907:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:12:51,801:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:13:04,511:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:13:20,194:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:13:30,383:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:13:53,058:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:14:09,960:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:14:18,666:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:14:33,667:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:14:45,483:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:14:59,985:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:15:11,290:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:15:26,856:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:15:42,129:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:15:51,822:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:16:05,189:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:16:16,937:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:16:27,725:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:16:43,012:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:16:59,162:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:17:18,772:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:17:32,765:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:17:47,878:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:17:59,871:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:18:16,486:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-31 13:18:25,230:Client-EnsembleBuilder] No runs were available to build an ensemble from
#           rank  ensemble_weight  type  cost duration
# model_id
# 1            1              1.0  <NA>  <NA>     <NA>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_15631/2881673376.py in <module>
#      16
#      17     #Report the models found by Auto-sklearn
# ---> 18     pprint(automl.show_models(), indent=4)
#      19
#      20     #Report statistics about the search
#
# ~/anaconda3/envs/atml_autosklearn/lib/python3.7/site-packages/autosklearn/estimators.py in show_models(self)
#     886         """  # noqa: E501
#     887
# --> 888         return self.automl_.show_models()
#     889
#     890     def get_models_with_weights(self):
#
# ~/anaconda3/envs/atml_autosklearn/lib/python3.7/site-packages/autosklearn/automl.py in show_models(self)
#    2167         if not table_dict:
#    2168             raise RuntimeError(
# -> 2169                 "No model found. Try increasing 'time_left_for_this_task'."
#    2170             )
#    2171
#
# RuntimeError: No model found. Try increasing 'time_left_for_this_task'.
