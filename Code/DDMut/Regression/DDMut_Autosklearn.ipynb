# %%
#####THIS CODE aims to run Autosklearn v1 on regressor data#####

#Adjustable parameters
main_path = '/home/korawich/Desktop/AutoML/automl_ddmut/'

time_left_for_this_task = 7200 #2 hrs
per_run_time_limit = 600
memory_limit = 9280

# %%
#Datafile #change here to use different data
data_path = main_path + 'AutoML/Dataset/DDMut_data/'
gbsig_path = main_path + 'Dataset/DDMut_data/Graph-based/'
result_path = main_path + 'Dataset/DDMut_data/Results/'
final_path = main_path + 'Dataset/DDMut_data/Final/'

#train_info_path  = final_path + 'train_info.csv'
#test_1_info_path = final_path + 'test_1_info.csv'
#test_2_info_path = final_path + 'test_2_info.csv'
#test_3_info_path = final_path + 'test_3_info.csv'

train_X_path  = final_path + 'final_train_X.csv'
test_1_X_path = final_path + 'final_test_1_X.csv'
test_2_X_path = final_path + 'final_test_2_X.csv'
test_3_X_path = final_path + 'final_test_3_X.csv'

train_y_path  = final_path + 'train_y.csv'
test_1_y_path = final_path + 'test_1_y.csv'
test_2_y_path = final_path + 'test_2_y.csv'
test_3_y_path = final_path + 'test_3_y.csv'

# %%
import numpy as np
import pandas as pd

from pprint import pprint

import sklearn.datasets
import sklearn.metrics

import autosklearn.regression

import warnings
warnings.filterwarnings('ignore')

# %%
#Code path 
alg_path = main_path + 'Algorithm/Auto-sklearn/'

# %% [markdown]
# loading data

# %%
X_train = pd.read_csv(train_X_path, index_col=0)
X_test_1 = pd.read_csv(test_1_X_path, index_col=0)
X_test_2 = pd.read_csv(test_2_X_path, index_col=0)
X_test_3 = pd.read_csv(test_3_X_path, index_col=0)

y_train = pd.read_csv(train_y_path, index_col=0)
y_test_1 = pd.read_csv(test_1_y_path, index_col=0)
y_test_2 = pd.read_csv(test_2_y_path, index_col=0)
y_test_3 = pd.read_csv(test_3_y_path, index_col=0)

# %%
#Check size of datasets
print('X_train.shape = ', X_train.shape)
print('X_test_1.shape = ', X_test_1.shape)
print('X_test_2.shape = ', X_test_2.shape)
print('X_test_3.shape = ', X_test_3.shape)
# Out:
# X_train.shape =  (9028, 896)
# X_test_1.shape =  (552, 896)
# X_test_2.shape =  (1304, 896)
# X_test_3.shape =  (2024, 896)

# %%
#load list of features
feat_list_path = main_path + 'Dataset/DDMut_data/Feat_list/'
gbsig_feat_list_path = feat_list_path + 'gbsig_feat_list.csv'
seq_feat_list_path = feat_list_path + 'seq_feat_list.csv'
str_feat_list_path = feat_list_path + 'str_feat_list.csv'

all_feat_result_path = result_path + 'tpot_default_params.csv'
gbsig_feat_result_path = result_path + 'tpot_default_params_gbsig.csv'
seq_feat_result_path = result_path + 'tpot_default_params_seq.csv'
str_feat_result_path = result_path + 'tpot_default_params_str.csv'

gbs_feat = pd.read_csv(gbsig_feat_list_path, index_col=0)
seq_feat = pd.read_csv(seq_feat_list_path, index_col=0)
str_feat = pd.read_csv(str_feat_list_path, index_col=0)
all_feat = pd.concat([seq_feat, str_feat, gbs_feat], ignore_index=True)

# %%
features_sets = [
    ('all_feat', all_feat, all_feat_result_path),
    ('seq_feat', seq_feat, seq_feat_result_path),
    ('str_feat', str_feat, str_feat_result_path),
    ('gbs_feat', gbs_feat, gbsig_feat_result_path)
]

# %% [markdown]
# Autosklearn

# %%
#Set search space -> #same as in table 18 of Autosklearn 2.0 paper (2020)
#It's only using iterative models and only preprocessing to encode data into suitable format
#https://arxiv.org/pdf/2007.04074
#But table 18 is classification. We adapt them to regression counterpart.

search_space_dict = {
            'regressor': [
                "extra_trees", 
                "gradient_boosting",
                "mlp",
                #"passive_aggressive", #No PA in regression
                "random_forest",
                "sgd"],
            'feature_preprocessor': ["no_preprocessing"]
}

# %%
automl = autosklearn.regression.AutoSklearnRegressor(
    ensemble_size=3, #use in the paper, always choosing the current best model
    initial_configurations_via_metalearning=0,
    n_jobs=-1,
    allow_string_features=False,
    time_left_for_this_task=time_left_for_this_task, #need to be changed
    per_run_time_limit=per_run_time_limit, #need to be changed
    resampling_strategy="cv",
    resampling_strategy_arguments={"folds": 5}, #should be ten
    seed=1,
    include=search_space_dict,
    exclude=None,
    delete_tmp_folder_after_terminate=False,
    memory_limit=memory_limit)

# %%
results = []
for feat_name, feat_list, result_path in features_sets:
    print('running - feat_name: ', feat_name)
    X_train_sel  = X_train[feat_list.values.flatten()]
    X_test_1_sel = X_test_1[feat_list.values.flatten()]
    X_test_2_sel = X_test_2[feat_list.values.flatten()]
    X_test_3_sel = X_test_3[feat_list.values.flatten()]
     
    automl.fit(X_train_sel, y_train, dataset_name="ddmut")
    
    print(automl.leaderboard())
    
    #During fit(), models are fit on individual cross-validation folds.
    #Refit use models on whole datasets
    automl.refit(X_train_sel.copy(), y_train)
    
    #Report the models found by Auto-sklearn
    pprint(automl.show_models(), indent=4)
    
    #Report statistics about the search
    print(automl.sprint_statistics())
    
    #Test on a blind test
    y_pred_test_1 = automl.predict(X_test_1_sel)
    rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_test_1))
    r2_1 = r2_score(y_test_1, y_pred_test_1)
    pearson_corr_1, _ = pearsonr(y_test_1.values.flatten(), y_pred_test_1.flatten())
    print('score for test 1 - RMSE = ', rmse_1, ' - R2 = ', r2_1, ' - Pearson = ', pearson_corr_1)

    y_pred_test_2 = automl.predict(X_test_2_sel)
    rmse_2 = np.sqrt(mean_squared_error(y_test_2, y_pred_test_2))
    r2_2 = r2_score(y_test_2, y_pred_test_2)
    pearson_corr_2, _ = pearsonr(y_test_2.values.flatten(), y_pred_test_2.flatten())
    print('score for test 2 - RMSE = ', rmse_2, ' - R2 = ', r2_2, ' - Pearson = ', pearson_corr_2)
    
    y_pred_test_3 = automl.predict(X_test_3_sel)
    rmse_3 = np.sqrt(mean_squared_error(y_test_3, y_pred_test_3))
    r2_3 = r2_score(y_test_3, y_pred_test_3)
    pearson_corr_3, _ = pearsonr(y_test_3.values.flatten(), y_pred_test_3.flatten())
    print('score for test 2 - RMSE = ', rmse_3, ' - R2 = ', r2_3, ' - Pearson = ', pearson_corr_3)
    
    #10-fold CV
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    rmse_scores = []
    r2_scores = []
    pearson_corrs = []
    
    for train_index, test_index in kfold.split(X_train_sel[feat_list.values.flatten()]):
        X_train_fold, X_test_fold = X_train_sel[feat_list.values.flatten()].loc[train_index], X_train_sel[feat_list.values.flatten()].loc[test_index]
        y_train_fold, y_test_fold = y_train.loc[train_index], y_train.loc[test_index]
        
        # Train the model on the current fold
        exported_pipeline.fit(X_train_fold, y_train_fold)
        y_pred_fold = exported_pipeline.predict(X_test_fold)
        
        # Calculate RMSE, R2, and Pearson correlation
        rmse = np.sqrt(mean_squared_error(y_test_fold, y_pred_fold))
        r2 = r2_score(y_test_fold, y_pred_fold)
        pearson_corr, _ = pearsonr(y_test_fold.values.flatten(), y_pred_fold.flatten())
        
        # Store the scores
        rmse_scores = np.append(rmse_scores, rmse)
        r2_scores = np.append(r2_scores, r2)
        pearson_corrs = np.append(pearson_corrs, pearson_corr)
        
    results.append({
        "Method": "TPOT",
        "Feat set": feat_name,
        "Model params": exported_pipeline,
        "CV Mean RMSE (10-fold)": round(np.mean(rmse_scores), 3), 
        "CV Std RMSE (10-fold)": round(np.std(rmse_scores), 3),
        "CV Mean R2 (10-fold)": round(np.mean(r2_scores), 3),
        "CV Std R2 (10-fold)": round(np.std(r2_scores), 3),
        "CV Mean Pearson (10-fold)": round(np.mean(pearson_corrs), 3),
        "CV Std Pearson (10-fold)": round(np.std(pearson_corrs), 3),
        "Test 1 RMSE": round(rmse_1, 3),
        "Test 1 R2"  : round(r2_1, 3),
        "Test 1 Pearson" : round(pearson_corr_1, 3),
        "Test 2 RMSE": round(rmse_2, 3),
        "Test 2 R2"  : round(r2_2, 3),
        "Test 2 Pearson" : round(pearson_corr_2, 3),
        "Test 3 RMSE": round(rmse_3, 3),
        "Test 3 R2"  : round(r2_3, 3),
        "Test 3 Pearson" : round(pearson_corr_3, 3)
        })
    results_df = pd.DataFrame(results)
    
    results_df_autosklearn_save_path = result_path + 'Autosklearn_ddmut_results.csv'
    results_df.to_csv(results_df_autosklearn_save_path)
# Out:
# running - feat_name:  all_feat
# [WARNING] [2024-08-29 13:48:49,548:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:48:53,993:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:48:59,433:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:04,309:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:08,920:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:13,974:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:19,303:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:24,226:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:29,549:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:34,570:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:39,504:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:44,692:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:50,297:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:49:55,362:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:00,713:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:05,918:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:10,596:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:16,466:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:21,952:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:28,407:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:29,471:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:35,457:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:40,839:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:46,834:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:55,051:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:57,349:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:50:58,437:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:03,852:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:04,936:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:10,003:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:15,347:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:16,441:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:21,505:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:26,864:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:32,443:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:38,355:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:43,201:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:48,518:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:53,956:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:51:59,261:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:52:05,014:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:52:10,871:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:52:16,896:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:52:17,989:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13:52:23,758:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 13
Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:37:49,592:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:37:52,028:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:37:59,407:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:06,767:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:13,852:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:16,593:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:18,883:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:22,110:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:29,561:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:36,909:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:44,787:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:47,279:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:49,855:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:52,316:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:38:59,099:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:01,506:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:08,899:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:11,393:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:13,860:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:16,869:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:23,503:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:31,464:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:33,860:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:36,438:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:38,859:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:41,431:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:49,108:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:51,236:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:39:58,947:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:06,418:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:14,265:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:20,926:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:28,412:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:36,441:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:38,974:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:46,783:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:53,049:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:40:55,553:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:02,927:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:10,931:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:13,345:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:15,777:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:18,277:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:21,893:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:24,459:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:32,664:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:35,927:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:42,501:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:44,964:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:47,447:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:49,933:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:41:57,433:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:04,736:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:07,787:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:09,543:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:17,052:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:19,579:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:22,600:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:29,479:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:36,881:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:45,876:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:47,933:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:50,399:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:42:58,319:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:05,087:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:07,937:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:15,136:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:22,576:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:25,114:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:28,449:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:30,872:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:33,213:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:35,049:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:37,497:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:40,543:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:42,723:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:51,077:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:43:53,549:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:00,962:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:08,446:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:10,931:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:18,052:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:20,579:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:28,141:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:30,526:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:33,081:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:35,742:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:42,345:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:44,970:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:44:52,567:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:00,507:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:03,081:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:06,348:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:08,859:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:15,596:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:17,957:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:20,564:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:27,948:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:35,454:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:42,859:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:50,449:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:45:52,953:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:01,358:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:08,937:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:16,459:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:18,979:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:22,315:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:24,879:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:32,406:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:34,448:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:42,002:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:49,456:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:46:57,074:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:00,003:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:01,961:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:09,419:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:17,931:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:20,353:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:22,842:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:25,707:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:28,395:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:35,948:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:43,426:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:45,876:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:48,529:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:51,580:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:53,900:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:56,527:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:47:59,979:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:48:06,915:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:48:10,114:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:48:12,450:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:48:20,066:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:48:28,474:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2024-08-29 15:48:35,949:Client-EnsembleBuilder] No runs were available to build an ensemble from
#           rank  ensemble_weight  type  cost duration
# model_id
# 1            1              1.0  <NA>  <NA>     <NA>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_7906/3749066027.py in <module>
#      16
#      17     #Report the models found by Auto-sklearn
# ---> 18     pprint(automl.show_models(), indent=4)
#      19
#      20     #Report statistics about the search
#
# ~/anaconda3/envs/atml_autosklearn/lib/python3.7/site-packages/autosklearn/estimators.py in show_models(self)
#     886         """  # noqa: E501
#     887
# --> 888         return self.automl_.show_models()
#     889
#     890     def get_models_with_weights(self):
#
# ~/anaconda3/envs/atml_autosklearn/lib/python3.7/site-packages/autosklearn/automl.py in show_models(self)
#    2167         if not table_dict:
#    2168             raise RuntimeError(
# -> 2169                 "No model found. Try increasing 'time_left_for_this_task'."
#    2170             )
#    2171
#
# RuntimeError: No model found. Try increasing 'time_left_for_this_task'.
